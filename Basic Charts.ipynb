# %%
import numpy as np

# %%
import pylab as plt
import random, datetime
import statsmodels.api as sm
from scipy.stats import norm
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
# %matplotlib inline

# %%
str(3)
int('5')
float('7.2')
# Out:
# '3'

# %%
def squarePlus(n):
    return n**2 + 1
squarePlus(2)
r = [squarePlus(i) for i in range(10)]
r = map(squarePlus, range(10))

r = []
i=0
while i<10:
    r.append(squarePlus(i))
    i+=1

# %%
def squarePlus(n):
    return n**2 + 1

squarePlus(2)
# Out:
# 5

# %%
r = [squarePlus(i) for i in range(10)]

# %%
def squarePlus(n):
    return n**2 + 1

squarePlus(2)

r = [squarePlus(i) for i in range(10)]

# %%
def squarePlus(n):
    return n**2 + 1
r = [squarePlus(i) for i in range(10)]

r = []

# %%
r = [squarePlus(i) for i in range(10)]

# %%
r = []
i = 0
while i < 10:
    r.append(squarePlus(i))
    i += 1

# %%
def OLSRegressPlot(x,y,col,xlab,ylab):
    xx = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,xx).fit()
    constant, beta = res.params
    r2 = res.rsquared
    lab = r'$slope = %.2f, \,R^2 = %.2f$' %(beta,r2)
    plt.scatter(x,y,s=60,facecolors='none', edgecolors=col)
    plt.plot(x,constant + x*beta,"red",label=lab)
    plt.legend(loc = 'upper left',fontsize=16)
    plt.xlabel(xlab,size=16)
    plt.ylabel(ylab,size=16)

fig = plt.figure(figsize=(7, 7),facecolor='white')
OLSRegressPlot(x,y,'RoyalBlue',r'$x$',r'$y$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 14
#      11     plt.ylabel(ylab,size=16)
#      13 fig = plt.figure(figsize=(7, 7),facecolor='white')
# ---> 14 OLSRegressPlot(x,y,'RoyalBlue',r'$x$',r'$y$')
#      15 plt.show()
#
# NameError: name 'x' is not defined

# %%
data = norm.rvs(10.0, 2.5, size=5000)

# %%
mu, std = norm.fit(data)

# %%
fig = plt.figure(figsize=(7, 7),facecolor='white')
plt.hist(data, bins=25, normed=True, alpha=0.6, color='g')
x = np.linspace(min(data), max(data), 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2)
title = r"$\mu = %.2f, \,  \sigma = %.2f$" % (mu, std)
plt.title(title,size=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 fig = plt.figure(figsize=(7, 7),facecolor='white')
# ----> 2 plt.hist(data, bins=25, normed=True, alpha=0.6, color='g')
#       3 x = np.linspace(min(data), max(data), 100)
#       4 p = norm.pdf(x, mu, std)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2648         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2649         color=color, label=label, stacked=stacked,
#    2650         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6944, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6942 if patch:
#    6943     p = patch[0]
# -> 6944     p._internal_update(kwargs)
#    6945     if lbl is not None:
#    6946         p.set_label(lbl)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'normed'

# %%
fig = plt.figure(figsize=(6,4))

# %%
ax_1 = fig.add_subplot(2, 2, 1)
ax_2 = fig.add_subplot(2, 2, 2)
ax_3 = fig.add_subplot(2, 2, 3)

# %%
plt.rc('figure', figsize=(10, 10))

# 若想要一次繪製大量參數，可以使用 dict 來一次傳入
font_options = {'family': 'Noto Serif',
                'weight': 'bold',
                'size': 'small'}
plt.rc('font', **font_options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 7
#       3 # 若想要一次繪製大量參數，可以使用 dict 來一次傳入
#       4 font_options = {'family': 'Noto Serif',
#       5                 'weight': 'bold',
#       6                 'size': 'small'}
# ----> 7 plt.rc('font', **font_options)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:589, in rc(group, **kwargs)
#     587 @_copy_docstring_and_deprecators(matplotlib.rc)
#     588 def rc(group, **kwargs):
# --> 589     matplotlib.rc(group, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1050, in rc(group, **kwargs)
#    1048 key = '%s.%s' % (g, name)
#    1049 try:
# -> 1050     rcParams[key] = v
#    1051 except KeyError as err:
#    1052     raise KeyError(('Unrecognized key "%s" for group "%s" and '
#    1053                     'name "%s"') % (key, g, name)) from err
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:722, in RcParams.__setitem__(self, key, val)
#     720         cval = self.validate[key](val)
#     721     except ValueError as ve:
# --> 722         raise ValueError(f"Key {key}: {ve}") from None
#     723     self._set(key, cval)
#     724 except KeyError as err:
#
# ValueError: Key font.size: Could not convert 'small' to float

# %%
plt.plot([1, 2, 3,4])

# %%
plt.plot([1, 2, 3,4])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.ylabel('y label')
plt.xlabel('x label')
# Out:
# Text(0.5, 0, 'x label')

# %%
x = np.random.randn(50)

# %%
x
# Out:
# array([-1.25114896e+00, -2.27925589e-01,  7.68561342e-01, -2.36132078e-01,
#        -9.38832316e-01,  1.48598488e+00, -6.47850538e-01,  1.21337037e+00,
#         7.48293245e-01,  1.00213552e+00, -3.94805624e-01,  2.70358584e-01,
#        -2.07556318e-01, -8.62824916e-01,  9.14419423e-01,  1.61370944e-05,
#         1.16778177e+00,  1.66895856e+00, -1.98620428e-01,  1.24834723e-01,
#        -4.28491480e-01, -5.42818769e-01,  3.60669417e-01,  4.77647062e-01,
#        -4.21247503e-01, -2.11933660e-01, -8.64260503e-01,  1.13349124e+00,
#        -1.03894768e+00,  8.56125675e-01,  6.80320939e-01, -2.26332156e-01,
#         7.69446225e-04, -2.87112877e-01, -4.47290778e-01, -2.93375482e-01,
#        -8.31321459e-01,  8.26839967e-01,  7.13004936e-01, -1.71577064e+00,
#        -1.85678348e+00,  4.89207930e-01, -1.53772554e+00, -3.34748236e-01,
#         8.62979126e-01,  1.23578121e-01,  2.66614400e-01, -1.54392815e+00,
#        -3.60059329e-01,  1.35276107e+00])

# %%
y = np.random.randn(50) + 3*x

# %%
def OLSRegressPlot(x,y,col,xlab,ylab):
    xx = sm.add_constant(x, prepend=True)
    res = sm.OLS(y,xx).fit()
    constant, beta = res.params
    r2 = res.rsquared
    lab = r'$slope = %.2f, \,R^2 = %.2f$' %(beta,r2)
    plt.scatter(x,y,s=60,facecolors='none', edgecolors=col)
    plt.plot(x,constant + x*beta,"red",label=lab)
    plt.legend(loc = 'upper left',fontsize=16)
    plt.xlabel(xlab,size=16)
    plt.ylabel(ylab,size=16)

fig = plt.figure(figsize=(7, 7),facecolor='white')
OLSRegressPlot(x,y,'RoyalBlue',r'$x$',r'$y$')
plt.show()
